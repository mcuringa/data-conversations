# %%
import pandas as pd
import schools
df = schools.load_demographics()
df
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# /usr/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
# df = df[['dbn', 'school_name', 'year', 'total_enrollment',
#        'female', 'female_1', 'male',
#        'male_1', 'asian', 'asian_1', 'black', 'black_1', 'hispanic',
#        'hispanic_1', 'multiple_race_categories', 'multiple_race_categories_1',
#        'white', 'white_1', 'students_with_disabilities',
#        'students_with_disabilities_1', 'english_language_learners',
#        'english_language_learners_1', 'poverty', 'poverty_1',
#          'non_white', 'black_hispanic',
#        'white_asian', 'non_white_asian',
#        'economic_need_index', 'pk', 'elementary', 'middle', 'hs', 'ay',
#        'district', 'school_num', 'boro', 'boro_name', 'school_type',
#        'clean_name', 'short_name']]


demo_cols = ['total_enrollment',
       'female_1',
       'male_1', 'asian_1',  'black_1',
       'hispanic_1', 'multiple_race_categories_1',
       'white_1', 
       'students_with_disabilities_1', 
       'english_language_learners_1', 'poverty_1']

d13 = df.query("district==13")

def changes(a):
    b = df.query(f"dbn=='{a.dbn}' and ay=={a.ay - 1}")
    if len(b) == 0: # nothing to do, no data for next year
        return
    for col in demo_cols:
        if col in a and col in b:
            a[col + "_yr_change"] = a[col] - b[col]
        else:
            print(col, dbn, ay)
    
df.query("ay==2015").poverty_1.unique()
# df = df.apply(changes, axis=1)
# df[["dbn", "school_name", "ay", "poverty_1_yr_change"]]
# Out:
# array(['84.7%', '80.4%', '60.8%', 'Above 95%', '93.0%', '54.1%', '92.8%',
#        '78.7%', '70.6%', '86.7%', '88.1%', '22.1%', '87.3%', '47.9%',
#        '39.0%', '46.2%', '69.3%', '88.3%', '69.6%', '71.2%', '90.1%',
#        '35.1%', '27.3%', '73.8%', '41.5%', '61.5%', '16.7%', '6.6%',
#        '28.2%', '46.6%', '8.4%', 'Below 5%', '61.7%', '85.5%', '47.6%',
#        '11.5%', '55.8%', '50.1%', '9.3%', '34.8%', '45.4%', '80.1%',
#        '48.5%', '72.0%', '77.0%', '14.1%', '40.7%', '11.7%', '44.2%',
#        '37.3%', '8.5%', '43.0%', '21.4%', '36.1%', '40.0%', '11.2%',
#        '14.6%', '6.8%', '7.1%', '31.6%', '76.9%', '84.1%', '41.9%',
#        '10.0%', '71.3%', '90.3%', '78.3%', '71.1%', '79.8%', '60.1%',
#        '28.9%', '76.2%', '83.8%', '11.0%', '12.5%', '67.2%', '74.2%',
#        '42.5%', '19.7%', '82.5%', '62.1%', '93.6%', '11.1%', '84.2%',
#        '76.3%', '18.2%', '34.4%', '50.8%', '32.3%', '75.3%', '21.8%',
# ...
