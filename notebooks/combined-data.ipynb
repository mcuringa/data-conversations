# %%
import pandas as pd
import schools
df = schools.load_demographics()
df.head()
# Out:
#       dbn                school_name  year  total_enrollment  \
# 0  01M015  P.S. 015 Roberto Clemente  2015               176
# 1  01M015  P.S. 015 Roberto Clemente  2016               178
# 2  01M015  P.S. 015 Roberto Clemente  2017               190
# 3  01M015  P.S. 015 Roberto Clemente  2018               174
# 4  01M015  P.S. 015 Roberto Clemente  2019               190
#
#    grade_3k_pk_half_day_full  grade_k  grade_1  grade_2  grade_3  grade_4  \
# 0                         14       32       33       39       23       17
# 1                         17       28       33       27       31       24
# 2                         17       28       32       33       23       31
# 3                         13       20       33       30       30       20
# 4                         14       29       28       38       33       29
#
#    ...         clean_name  short_name  non_white  non_white_1  black_hispanic  \
# ...

# %%
math_df = schools.load_math_tests()
math_df.head()
# Out:
#       dbn grade  year category  number_tested mean_scale_score level_1  \
# 0  01M015     3  2013      all             27              278      16
# 1  01M015     3  2014      all             18              286       6
# 2  01M015     3  2015      all             17              280      10
# 3  01M015     3  2016      all             21              275      13
# 4  01M015     3  2017      all             29              302       8
#
#   level_1_1 level_2 level_2_1 level_3 level_3_1 level_4 level_4_1 level_3_4  \
# 0      59.3      11      40.7       0       0.0       0       0.0         0
# 1      33.3       9      50.0       2      11.1       1       5.6         3
# 2      58.8       4      23.5       2      11.8       1       5.9         3
# 3      61.9       4      19.0       4      19.0       0       0.0         4
# 4      27.6       9      31.0       7      24.1       5      17.2        12
#
#   level_3_4_1
# 0         0.0
# 1        16.7
# 2        17.6
# 3        19.0
# ...

# %%
ela_df = schools.load_ela_tests()
ela_df.head()
# Out:
#       dbn grade  year category  number_tested mean_scale_score level_1  \
# 0  01M015     3  2013      all             27              289      14
# 1  01M015     3  2014      all             18              285      10
# 2  01M015     3  2015      all             16              282       9
# 3  01M015     3  2016      all             20              293      10
# 4  01M015     3  2017      all             27              302      10
#
#   level_1_1 level_2 level_2_1 level_3 level_3_1 level_4 level_4_1 level_3_4  \
# 0      51.9      11      40.7       2       7.4       0       0.0         2
# 1      55.6       8      44.4       0       0.0       0       0.0         0
# 2      56.3       5      31.3       2      12.5       0       0.0         2
# 3      50.0       6      30.0       4      20.0       0       0.0         4
# 4      37.0       8      29.6       7      25.9       2       7.4         9
#
#   level_3_4_1
# 0         7.4
# 1         0.0
# 2        12.5
# 3        20.0
# ...

# %%
combined = schools.combine_test_data(df, math_df, "math")
combined.head()
# Out:
#       dbn                school_name  year  total_enrollment  \
# 0  01M015  P.S. 015 Roberto Clemente  2015               176
# 1  01M015  P.S. 015 Roberto Clemente  2016               178
# 2  01M015  P.S. 015 Roberto Clemente  2017               190
# 3  01M015  P.S. 015 Roberto Clemente  2018               174
# 4  01M015  P.S. 015 Roberto Clemente  2019               190
#
#    grade_3k_pk_half_day_full  grade_k  grade_1  grade_2  grade_3  grade_4  \
# 0                         14       32       33       39       23       17
# 1                         17       28       33       27       31       24
# 2                         17       28       32       33       23       31
# 3                         13       20       33       30       30       20
# 4                         14       29       28       38       33       29
#
#    ...  math_never_ell_grade_8_level_1  math_never_ell_grade_8_level_1_1  \
# 0  ...                             NaN                               NaN
# ...

# %%
combined = schools.combine_test_data(df, ela_df, "ela")
combined.head()
# Out:
#       dbn                school_name  year  total_enrollment  \
# 0  01M015  P.S. 015 Roberto Clemente  2015               176
# 1  01M015  P.S. 015 Roberto Clemente  2016               178
# 2  01M015  P.S. 015 Roberto Clemente  2017               190
# 3  01M015  P.S. 015 Roberto Clemente  2018               174
# 4  01M015  P.S. 015 Roberto Clemente  2019               190
#
#    grade_3k_pk_half_day_full  grade_k  grade_1  grade_2  grade_3  grade_4  \
# 0                         14       32       33       39       23       17
# 1                         17       28       33       27       31       24
# 2                         17       28       32       33       23       31
# 3                         13       20       33       30       30       20
# 4                         14       29       28       38       33       29
#
#    ...  ela_current_ell_grade_8_level_1  ela_current_ell_grade_8_level_1_1  \
# ...

# %%
combined.to_feather("combined-test-data.feather")
