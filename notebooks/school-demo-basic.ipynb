# %%
import pandas as pd

# %%
# load the school demo data from the open api server
demo_url = "https://data.cityofnewyork.us/resource/45j8-f6um.csv"
df = pd.read_csv(demo_url)

# %%
df
# Out:
#         dbn                                        school_name     year  \
# 0    01M015                          P.S. 015 Roberto Clemente  2014-15
# 1    01M015                          P.S. 015 Roberto Clemente  2015-16
# 2    01M015                          P.S. 015 Roberto Clemente  2016-17
# 3    01M015                          P.S. 015 Roberto Clemente  2017-18
# 4    01M015                          P.S. 015 Roberto Clemente  2018-19
# ..      ...                                                ...      ...
# 995  04M108  P.S. 108 Assemblyman Angelo Del Toro Education...  2014-15
# 996  04M108  P.S. 108 Assemblyman Angelo Del Toro Education...  2015-16
# 997  04M108  P.S. 108 Assemblyman Angelo Del Toro Education...  2016-17
# 998  04M108  P.S. 108 Assemblyman Angelo Del Toro Education...  2017-18
# 999  04M108  P.S. 108 Assemblyman Angelo Del Toro Education...  2018-19
#
#      total_enrollment  grade_pk_half_day_full_day  grade_k  grade_1  grade_2  \
# 0                 183                          18       27       47       31
# 1                 176                          14       32       33       39
# 2                 178                          17       28       33       27
# 3                 190                          17       28       32       33
# 4                 174                          13       20       33       30
# ..                ...                         ...      ...      ...      ...
# 995               626                          18       36       52       54
# 996               594                          17       46       31       48
# 997               513                          17       38       45       30
# 998               452                          13       31       34       40
# 999               470                          53       33       37       36
#
#      grade_3  grade_4  ...  multiple_race_categories_1  white  white_1  \
# 0         19       17  ...                       0.005      2    0.011
# 1         23       17  ...                       0.017      2    0.011
# 2         31       24  ...                       0.022      4    0.022
# 3         23       31  ...                       0.011      6    0.032
# 4         30       20  ...                       0.006      6    0.034
# ..       ...      ...  ...                         ...    ...      ...
# 995       53       57  ...                       0.014     11    0.018
# 996       54       54  ...                       0.012      8    0.013
# 997       53       44  ...                       0.008      9    0.018
# 998       29       47  ...                       0.007      8    0.018
# 999       35       34  ...                       0.013     16    0.034
#
#      students_with_disabilities  students_with_disabilities_1  \
# 0                            64                         0.350
# 1                            60                         0.341
# 2                            51                         0.287
# 3                            49                         0.258
# 4                            38                         0.218
# ..                          ...                           ...
# 995                         155                         0.248
# 996                         179                         0.301
# 997                         156                         0.304
# 998                         148                         0.327
# 999                         147                         0.313
#
#      english_language_learners  english_language_learners_1  poverty  \
# 0                           17                        0.093      169
# 1                           16                        0.091      149
# 2                           12                        0.067      152
# 3                            8                        0.042      161
# 4                            8                        0.046      145
# ..                         ...                          ...      ...
# 995                         77                        0.123      497
# 996                         77                        0.130      479
# 997                         59                        0.115      413
# 998                         41                        0.091      405
# 999                         32                        0.068      406
#
#      poverty_1  economic_need_index
# 0        0.923                0.930
# 1        0.847                0.889
# 2        0.854                0.882
# 3        0.847                0.890
# 4        0.833                0.880
# ..         ...                  ...
# 995      0.794                0.844
# 996      0.806                0.867
# 997      0.805                0.856
# 998      0.896                0.928
# 999      0.864                0.918
#
# [1000 rows x 39 columns]
