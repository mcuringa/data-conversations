# %%
import pandas as pd
import schools
df = schools.load_demographics()
# school_names = df[["dbn","school_name", "school_num", "school_type", "short_name"]]
# school_names.drop_duplicates()

# df.school_name.str.lower()

# list(df.columns)

# %%
t = schools.find_school(df, "jhs 88")
# t = t.query("match > 80")
# t[["dbn", "clean_name", "match"]]
t = pd.DataFrame(t)
t[["dbn","short_name", "clean_name", "school_name"]]
pd.DataFrame.to_json(t, orient='records')
# Out:
# '[{"dbn":"15K088","school_name":"J.H.S. 088 Peter Rouget","year":"2019-20","total_enrollment":1418,"grade_3k_pk_half_day_full":0,"grade_k":0,"grade_1":0,"grade_2":0,"grade_3":0,"grade_4":0,"grade_5":0,"grade_6":482,"grade_7":522,"grade_8":414,"grade_9":0,"grade_10":0,"grade_11":0,"grade_12":0,"female":658,"female_1":0.464,"male":760,"male_1":0.536,"asian":287,"asian_1":0.202,"black":186,"black_1":0.131,"hispanic":712,"hispanic_1":0.502,"multiple_race_categories":32,"multiple_race_categories_1":0.023,"white":201,"white_1":0.142,"students_with_disabilities":326,"students_with_disabilities_1":0.23,"english_language_learners":169,"english_language_learners_1":0.119,"poverty":"1022","poverty_1":"72.1%","economic_need_index":"73.8%","pk":false,"elementary":false,"middle":true,"hs":false,"ay":2019,"district":15,"school_num":88,"boro":"K","boro_name":"Brooklyn","school_type":"MS","clean_name":"jhs 88 peter rouget","short_name":"MS 88","non_white":1217,"black_hispanic":898,"white_asian":488,"non_white_asian":930,"match":48}]'

# %%
from fuzzywuzzy import fuzz

qry = "IS 88"

t = df.copy(deep=False)
# t["match"] = t.clean_name.apply(lambda sn: fuzz.partial_ratio(qry, sn))

t["match"] = t.short_name.apply(lambda sn: fuzz.ratio(qry, sn))
t = t.query("match > 50")

# t["match"] = t.clean_name.apply(lambda sn: fuzz.ratio(qry, sn))
t = t.sort_values(by=["match"], ascending=False)

t = t[["dbn","short_name", "clean_name", "school_name", "match"]]
t
# t.clean_name.unique()
# Out:
#          dbn short_name                                  clean_name  \
# 1983  09X088      PS 88  x088 - s silverstein little sparrow school
# 4247  18K068      IS 68                             isaac bildersee
# 1985  09X088      PS 88  x088 - s silverstein little sparrow school
# 3686  15K088      MS 88                         jhs 88 peter rouget
# 3685  15K088      MS 88                         jhs 88 peter rouget
# ...      ...        ...                                         ...
# 3868  15K821     MS 821                            sunset park prep
# 3867  15K821     MS 821                            sunset park prep
# 3866  15K821     MS 821                            sunset park prep
# 3865  15K821     MS 821                            sunset park prep
# 9090  84X718     PS 718    bronx charter school for better learning
#
#                                            school_name  match
# 1983  P.S. X088 - S. Silverstein Little Sparrow School     80
# 4247                          I.S. 068 Isaac Bildersee     80
# 1985  P.S. X088 - S. Silverstein Little Sparrow School     80
# 3686                           J.H.S. 088 Peter Rouget     80
# 3685                           J.H.S. 088 Peter Rouget     80
# ...                                                ...    ...
# 3868                                  Sunset Park Prep     55
# 3867                                  Sunset Park Prep     55
# 3866                                  Sunset Park Prep     55
# 3865                                  Sunset Park Prep     55
# 9090          Bronx Charter School for Better Learning     55
#
# [2030 rows x 5 columns]

# %%
# ms = df.query("ay == 2018 & school_type == 'MS' & district == 15")
# ms[["dbn","school_name", "school_num", "school_type", "short_name"]]

# %%
import re
sn = "brooklyn"
p = re.compile(r"^(.*?)\b([m|p|i]s)([0-9]*)\b(.*)$", re.IGNORECASE)
m = p.search(sn)
m.group(1, 2, 3, 4)
# print(m)
# sn.replace(m.group(0), "")

# "ps 9".count(r"[M|P|I])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d5e6127aed0f> in <module>
#       3 p = re.compile(r"^(.*?)\b([m|p|i]s)([0-9]*)\b(.*)$", re.IGNORECASE)
#       4 m = p.search(sn)
# ----> 5 m.group(1, 2, 3, 4)
#       6 # print(m)
#       7 # sn.replace(m.group(0), "")
#
# AttributeError: 'NoneType' object has no attribute 'group'
